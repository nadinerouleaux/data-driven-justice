# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('communities.csv', encoding="utf-8")

# %%
data.sort_values('0.2.2', ascending=False)
# Out:
#        8    ?    ?.1         Lakewoodcity   1  0.19  0.33  0.02   0.9  0.12  \
# 81    48    ?      ?           Vernoncity   1  0.00  0.42  0.21  0.65  0.04
# 1846  34   13  51000           Newarkcity  10  0.43  0.62  1.00  0.00  0.07
# 461    6    ?      ?         Commercecity   3  0.00  1.00  0.02  0.06  0.08
# 1133  12    ?      ?            Miamicity   6  0.56  0.49  0.53  0.48  0.04
# 908   29    ?      ?       KansasCitycity   5  0.68  0.33  0.58  0.49  0.07
# 1294  22    ?      ?       Alexandriacity   7  0.06  0.47  0.96  0.23  0.04
# 1118   1    ?      ?         Bessemercity   6  0.04  0.44  1.00  0.10  0.00
# 498    6    ?      ?    SanBernardinocity   3  0.25  0.62  0.31  0.40  0.24
# 954    1    ?      ?         Prichardcity   5  0.04  0.67  1.00  0.00  0.00
# 956    6    ?      ?    WestHollywoodcity   5  0.04  0.00  0.07  0.85  0.19
# 677   12    ?      ?            Daniacity   4  0.00  0.23  0.61  0.50  0.03
# ...

# %%
data = pd.read_csv('crim_hist.tsv', sep='\t', encoding="utf-8")

# %%
data
# Out:
#    unit,geo\time    2000      1999      1998      1997      1996      1995   \
# 0          NR,AT   560306   493246    479859    481549    485450    486433
# 1          NR,BE  1002660        :         :         :         :         :
# 2          NR,BG   148915   145035    159317    228219    184975    196346
# 3          NR,CH   317335   355255    378045    382769    356018    346634
# 4          NR,CY     4340     4212      4316      3910      4529      4033
# 5          NR,CZ   391469   426626    425930    403654    394267    375630
# 6          NR,DE  6264723  6302316   6456996   6586165   6647598   6668717
# 7          NR,DK   504231   494191    499167    531102    528488    538963
# 8          NR,EE    57799    51539     45721     40972     35411     39570
# 9          NR,EL   369137   373680    385681    377749    349476    329110
# 10         NR,ES  1852858  1895983   1865572   1823330   1770019   1659026
# ...

# %%
data.columns
# Out:
# Index(['unit,geo\time', '2000 ', '1999 ', '1998 ', '1997 ', '1996 ', '1995 ',
#        '1994 ', '1993 ', '1992 ', '1991 ', '1990 ', '1989 ', '1988 ', '1987 ',
#        '1986 ', '1985 ', '1984 ', '1983 ', '1982 ', '1981 ', '1980 ', '1979 ',
#        '1978 ', '1977 ', '1976 ', '1975 ', '1974 ', '1973 ', '1972 ', '1971 ',
#        '1970 ', '1969 ', '1968 ', '1967 ', '1966 ', '1965 ', '1964 ', '1963 ',
#        '1962 ', '1961 ', '1960 ', '1959 ', '1958 ', '1957 ', '1956 ', '1955 ',
#        '1954 ', '1953 ', '1952 ', '1951 ', '1950 '],
#       dtype='object')

# %%
years = ['2000 ', '1999 ', '1998 ', '1997 ', '1996 ', '1995 ',
       '1994 ', '1993 ', '1992 ', '1991 ', '1990 ', '1989 ', '1988 ', '1987 ',
       '1986 ', '1985 ', '1984 ', '1983 ', '1982 ', '1981 ', '1980 ', '1979 ',
       '1978 ', '1977 ', '1976 ', '1975 ', '1974 ', '1973 ', '1972 ', '1971 ',
       '1970 ', '1969 ', '1968 ', '1967 ', '1966 ', '1965 ', '1964 ', '1963 ',
       '1962 ', '1961 ', '1960 ', '1959 ', '1958 ', '1957 ', '1956 ', '1955 ',
       '1954 ', '1953 ', '1952 ', '1951 ', '1950 ']

# %%
for i in years:
    plt.plot(data['unit,geo\time', data[str(i)]])
# Out:
# 2000
# 1999
# 1998
# 1997
# 1996
# 1995
# 1994
# 1993
# 1992
# 1991
# 1990
# 1989
# 1988
# 1987
# 1986
# 1985
# 1984
# 1983
# 1982
# 1981
# 1980
# 1979
# 1978
# 1977
# 1976
# 1975
# 1974
# 1973
# 1972
# 1971
# 1970
# 1969
# 1968
# 1967
# 1966
# 1965
# 1964
# 1963
# 1962
# 1961
# 1960
# 1959
# 1958
# 1957
# 1956
# 1955
# 1954
# 1953
# 1952
# 1951
# 1950

# %%
data[1:1]
# Out:
# Empty DataFrame
# Columns: [unit,geo\time, 2000 , 1999 , 1998 , 1997 , 1996 , 1995 , 1994 , 1993 , 1992 , 1991 , 1990 , 1989 , 1988 , 1987 , 1986 , 1985 , 1984 , 1983 , 1982 , 1981 , 1980 , 1979 , 1978 , 1977 , 1976 , 1975 , 1974 , 1973 , 1972 , 1971 , 1970 , 1969 , 1968 , 1967 , 1966 , 1965 , 1964 , 1963 , 1962 , 1961 , 1960 , 1959 , 1958 , 1957 , 1956 , 1955 , 1954 , 1953 , 1952 , 1951 , 1950 ]
# Index: []
#
# [0 rows x 52 columns]

# %%
plt.plot(data.index, data['2000'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.4.2/lib/python3.4/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: '2000'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# !ls
# Out:
# 37685ENG_UntypedDataSet_23112017_155707.csv
# Directional Distribution - Standard Deviation Ellipse.twbx
# ESS5e03_3.spss
# ESS5e03_3.spss.zip
# ESS5e03_3.stata
# ESS5e03_3.stata.zip
# Hackathon.ipynb
# communities.csv
# communities.data
# communities.names
# communities.txt
# crim_hist.tsv
# crim_hist.tsv.gz
# sources

# %%
pd.read_csv('37685ENG_UntypedDataSet_23112017_155707.csv', sep=';', encoding="utf-8")
# Out:
#     ID   Periods  TotalVictimsOfCrimes_1  SingleVictims_2  MultipleVictims_3  \
# 0    0  1992JJ00                    24.3             18.5                5.9
# 1    1  1993JJ00                    25.0             19.1                6.0
# 2    2  1994JJ00                    26.0             20.8                5.2
# 3    3  1995JJ00                    25.9             20.2                5.7
# 4    4  1996JJ00                    23.1             18.6                4.6
# 5    5  1997JJ00                    25.5             20.4                5.2
# 6    6  1998JJ00                    26.2             20.7                5.4
# 7    7  1999JJ00                    26.2             20.6                5.5
# 8    8  2000JJ00                    25.7             20.7                5.0
# 9    9  2001JJ00                    24.9             19.6                5.4
# 10  10  2002JJ00                    27.2             21.4                5.8
# ...
